# %%
import scipy.misc as misc
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
# %matplotlib inline

# %%
gt = misc.imread('gt_8.png')
inp = misc.imread('inp_8.png')
pred = misc.imread('pred_8.png')
# Out:
# /Users/danny/Documents/devenv/tf_vir/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# /Users/danny/Documents/devenv/tf_vir/lib/python2.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# /Users/danny/Documents/devenv/tf_vir/lib/python2.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.imshow(inp)

# %%
plt.imshow(gt, cmap=cm.Paired ,vmin=0, vmax=151)
plt.colorbar()

# %%
plt.imshow(pred,cmap=cm.Paired ,vmin=0, vmax=151)
plt.colorbar()
